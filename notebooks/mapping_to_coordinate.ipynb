# %%
import pandas as pd
import xml.etree.ElementTree as ET
pd.set_option('display.max_rows', 4000)
import numpy as np
import urllib
import json
import requests, zipfile, io


dataset = pd.read_csv('free_parking_v0.0.3.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0  ID             street park_side  \
# 0           0   4       Tenth Street      Both
# 1           1   6    Eleventh Street      Both
# 2           3  11  Thirteenth Street      Both
# 3           4  12  Thirteenth Street      East
# 4           5  14       First Street      East
#
#                                         area_between  \
# 0  Lake Shore Blvd W and the first lane south the...
# 1               Lake Shore Blvd W and the first lane
# 2  Lake Shore Boulevard West and the first lane s...
# 3  Lake Shore Boulevard West and the first lane s...
# 4  Lake Shore Boulevard West and a point 26 metre...
#
#                              valid_time permited_time  permited_time_mins  \
# 0  9:00 a.m. to 6:00 p.m., Mon. to Sat.       2 hours                 120
# 1  9:00 a.m. to 6:00 p.m., Mon. to Sat.       2 hours                 120
# 2  9:00 a.m. to 6:00 p.m., Mon. to Sat.       2 hours                 120
# 3  9:00 a.m. to 6:00 p.m., Mon. to Sat.          None                   0
# 4  9:00 a.m. to 6:00 p.m., Mon. to Sat.       2 hours                 120
#
#                    start_zone                end_zone
# 0          lake shore blvd w    the first lane south
# 1          lake shore blvd w           the first lane
# 2  lake shore boulevard west    the first lane south
# 3  lake shore boulevard west    the first lane south
# 4  lake shore boulevard west          26 metres south

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyAO39JabxbxnlM1dnZrqKCxVhuAdGoCFlg')

# Geocoding an address
#geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# %%
geocode_result = gmaps.geocode('Thirteenth Street, Toronto')

# %%
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Thirteenth Street',
#     'short_name': 'Thirteenth St',
#     'types': ['route']},
#    {'long_name': 'Etobicoke',
#     'short_name': 'Etobicoke',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Toronto',
#     'short_name': 'Toronto',
#     'types': ['locality', 'political']},
#    {'long_name': 'Toronto Division',
#     'short_name': 'Toronto Division',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Ontario',
#     'short_name': 'ON',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Canada',
#     'short_name': 'CA',
#     'types': ['country', 'political']},
#    {'long_name': 'M8V',
#     'short_name': 'M8V',
#     'types': ['postal_code', 'postal_code_prefix']}],
#   'formatted_address': 'Thirteenth St, Toronto, ON M8V, Canada',
#   'geometry': {'bounds': {'northeast': {'lat': 43.6006827,
#      'lng': -79.50975489999999},
#     'southwest': {'lat': 43.5943995, 'lng': -79.5125662}},
#    'location': {'lat': 43.5970001, 'lng': -79.5108801},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 43.6006827, 'lng': -79.50975489999999},
#     'southwest': {'lat': 43.5943995, 'lng': -79.5125662}}},
#   'place_id': 'ChIJe__AyctJK4gRxnsnLBilS9o',
#   'types': ['route']}]
